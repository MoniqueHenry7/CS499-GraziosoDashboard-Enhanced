# %% [markdown]
# # CS 499 Computer Science Capstone
#
# ## Grazioso Salvare Rescue Match Recommendation Dashboard
#
# **Student:** Monique Henry
# **Enhancement Category:** Software Design and Engineering
#
# This notebook launches the enhanced CS 340 Grazioso Salvare artifact.
#
# The original dashboard was refactored into separate modules for:
#
# - application configuration
# - MongoDB data access
# - rescue recommendation rules
# - business and filtering logic
# - user-interface presentation
# - callback and interaction behavior
#
# The enhanced application adds a Rescue Match Recommendation System that
# evaluates and ranks animals using breed, age, sex, and shelter outcome
# criteria while preserving the original table, visualization, and map
# functionality.
#
# The modular architecture improves maintainability, readability,
# testability, security, usability, and future extensibility.

# %%
from app import create_app

# %%
app = create_app()
# Out:
# Connected to MongoDB successfully: aac.animals

# %%
app.run(
    host="127.0.0.1",
    port=8050,
    debug=False,
    jupyter_mode="external"
)
# Out:
# Dash app running on http://127.0.0.1:8050/
